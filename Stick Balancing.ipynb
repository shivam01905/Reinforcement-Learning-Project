# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in d:\reinforcementlearning\rl\lib\site-packages (1.5.0)
# Requirement already satisfied: gym==0.21 in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: numpy in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (1.22.3)
# Requirement already satisfied: matplotlib in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: torch>=1.8.1 in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (1.11.0)
# Requirement already satisfied: cloudpickle in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: pandas in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: pillow in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (9.1.0)
# Requirement already satisfied: tensorboard>=2.2.0 in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (2.8.0)
# Requirement already satisfied: ale-py~=0.7.4 in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (0.7.5)
# Requirement already satisfied: opencv-python in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (4.5.5.64)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: psutil in d:\reinforcementlearning\rl\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: importlib-metadata>=4.10.0 in d:\reinforcementlearning\rl\lib\site-packages (from ale-py~=0.7.4->stable-baselines3[extra]) (4.11.3)
# Requirement already satisfied: importlib-resources in d:\reinforcementlearning\rl\lib\site-packages (from ale-py~=0.7.4->stable-baselines3[extra]) (5.7.1)
# Requirement already satisfied: click in d:\reinforcementlearning\rl\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.1.2)
# Requirement already satisfied: tqdm in d:\reinforcementlearning\rl\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: requests in d:\reinforcementlearning\rl\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: AutoROM.accept-rom-license in d:\reinforcementlearning\rl\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: markdown>=2.6.8 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.6)
# Requirement already satisfied: grpcio>=1.24.3 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.44.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: protobuf>=3.6.0 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.20.0)
# Requirement already satisfied: absl-py>=0.4 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.6.5)
# Requirement already satisfied: setuptools>=41.0.0 in d:\reinforcementlearning\rl\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (57.4.0)
# Requirement already satisfied: typing-extensions in d:\reinforcementlearning\rl\lib\site-packages (from torch>=1.8.1->stable-baselines3[extra]) (4.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\reinforcementlearning\rl\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\reinforcementlearning\rl\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\reinforcementlearning\rl\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in d:\reinforcementlearning\rl\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\reinforcementlearning\rl\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.8)
# Requirement already satisfied: fonttools>=4.22.0 in d:\reinforcementlearning\rl\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.32.0)
# Requirement already satisfied: pytz>=2020.1 in d:\reinforcementlearning\rl\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.1)
# Requirement already satisfied: six in d:\reinforcementlearning\rl\lib\site-packages (from absl-py>=0.4->tensorboard>=2.2.0->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\reinforcementlearning\rl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\reinforcementlearning\rl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\reinforcementlearning\rl\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\reinforcementlearning\rl\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in d:\reinforcementlearning\rl\lib\site-packages (from importlib-metadata>=4.10.0->ale-py~=0.7.4->stable-baselines3[extra]) (3.8.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\reinforcementlearning\rl\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\reinforcementlearning\rl\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in d:\reinforcementlearning\rl\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\reinforcementlearning\rl\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.12)
# Requirement already satisfied: colorama in d:\reinforcementlearning\rl\lib\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\reinforcementlearning\rl\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\reinforcementlearning\rl\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.0)

# %%
import os
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from tqdm import tqdm

# %% [markdown]
# # 2. Load Environment

# %%
environment_name = "CartPole-v0"

# %%
env = gym.make(environment_name)

# %%
# !pip install pyglet

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:12.0
# Episode:2 Score:12.0
# Episode:3 Score:40.0
# Episode:4 Score:18.0
# Episode:5 Score:48.0

# %% [markdown]
# # Understanding The Environment
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py

# %%
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# 1

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([ 2.7092966e-01, -4.4323951e+37,  1.9755277e-01, -3.2199826e+38],
#       dtype=float32)

# %% [markdown]
# # 3. Train an RL Model

# %%
log_path = os.path.join('Training','Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2729 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1733        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009118118 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.000517    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.12        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 54.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1555        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010200096 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0645      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 34.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1494        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007723866 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 53.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1453         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0067746937 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.257        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0127      |
# |    value_loss           | 59.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007402912 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 57.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1405        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010825767 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 63.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008493928 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.77        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 31.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1393        |
# |    iterations           | 9           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007823807 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00876    |
# |    value_loss           | 30          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1386        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004153939 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00747    |
# |    value_loss           | 14.6        |
# -----------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model')

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load('PPO_model', env=env)

# %% [markdown]
# # 4. Evaluation

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# D:\ReinforcementLearning\rl\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # 5. Test Model

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([ 0.14756502,  0.33927318, -0.06138154, -0.47982508], dtype=float32)}]

# %%
model.predict(obs)
# Out:
# (array([0], dtype=int64), None)

# %%
env.close()

# %% [markdown]
# # 6. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_3')

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# ^C

# %% [markdown]
# # 7. Adding a callback to the training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 2844 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1768        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009442848 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00504     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.05        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 52.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1594        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009335554 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.0945      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 36.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1495         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0074304906 |
# |    clip_fraction        | 0.0896       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.627       |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0196      |
# |    value_loss           | 49.5         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0071998704 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.8         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0128      |
# |    value_loss           | 59.5         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 190

# %%
model_path = os.path.join('Training', 'Saved Models', 'best_model')
model = PPO.load(model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # 8. Changing Policies

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2241 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014541181 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.00283    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.99        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 20.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1017        |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018893111 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.644      |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0328     |
# |    value_loss           | 28.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 953         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012815017 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 43.4        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=194.00 +/- 12.00
# Episode length: 194.00 +/- 12.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 194        |
# |    mean_reward          | 194        |
# | time/                   |            |
# |    total_timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.01520369 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.559     |
# |    explained_variance   | 0.642      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.41       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0176    |
# |    value_loss           | 35.7       |
# ----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 878   |
# |    iterations      | 5     |
# |    time_elapsed    | 11    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011810878 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00867    |
# |    value_loss           | 14.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0151765505 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.642        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0085      |
# |    value_loss           | 8.16         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009573734 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.44        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00779    |
# |    value_loss           | 12.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 9           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012120249 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.314       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 3.48        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0074583646 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.512       |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.429        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000372    |
# |    value_loss           | 2.72         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 828   |
# |    iterations      | 10    |
# |    time_elapsed    | 24    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# # 9. Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 8873     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 71       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 10263    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 10397    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 10689    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 278      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 11576    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 407      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 11886    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 513      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 11961    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 600      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 12018    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 687      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 12208    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 820      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 12082    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 884      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 12126    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 960      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 12199    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 12375    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 12468    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 12521    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.306    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 12584    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 12607    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.218    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 12644    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1646     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.19     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 12612    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.148    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 12610    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 12610    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.078    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 12671    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 12607    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 12646    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 12588    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 12579    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2229     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 12628    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 12627    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 12688    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 12644    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 12691    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 12665    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 12729    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 12781    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 12799    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 12820    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 12745    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3240     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 12762    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 12748    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 12730    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 12725    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 12758    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 12739    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3812     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 12742    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 12720    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 12721    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 12750    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 12742    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 12730    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 12724    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 12731    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4561     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 12727    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 12701    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4690     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 12710    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 12669    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4819     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 12678    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 12675    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 12644    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 12637    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 12655    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5282     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 12697    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5376     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 12659    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5451     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 12654    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5512     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 12633    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 12648    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 12641    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5747     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 12654    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 12653    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5917     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 12624    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 12613    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 12607    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6138     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 12606    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6213     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 12610    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 12642    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 12642    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 12634    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 12666    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 12685    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 12713    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6910     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 12705    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 12697    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 12716    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 12700    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 12693    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 12706    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 12702    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 12714    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 12707    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 12715    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 12717    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 12766    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 12768    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 12755    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 12733    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 12741    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 12730    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 12713    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 12709    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8639     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 12719    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 12721    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 12714    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 12705    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8954     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 12709    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 12694    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 12713    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9214     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 12713    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 12716    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 12710    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9456     |
# ----------------------------------
# Eval num_timesteps=9520, episode_reward=9.60 +/- 0.80
# Episode length: 9.60 +/- 0.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 9520     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 12522    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9542     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 12504    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 12518    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 12510    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 12532    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 12529    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 12484    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 12480    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 12468    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 12471    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 12475    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 12479    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 12484    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10572    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 12474    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10651    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 12479    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 12487    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 12493    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 12496    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 12491    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 12489    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 12498    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 12483    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 12497    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 12504    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 12514    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 12511    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 12499    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 12497    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11865    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 12492    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 12505    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 12502    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 12501    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 12495    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 12509    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 12506    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 12476    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 12509    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 12503    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 12512    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12707    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 12512    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 12501    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 12511    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 12514    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 12514    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13099    |
# ----------------------------------
# ...
# |    fps              | 12511    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 12512    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 12507    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 12516    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 12520    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 12513    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 12506    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16232    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 12512    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 12510    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16388    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 12521    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 12528    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16625    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 12522    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 12533    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 12535    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 12531    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 12529    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 12534    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 12538    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 12528    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 12529    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 12536    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 12531    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 12534    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 12534    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 12530    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 12517    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 12518    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 12508    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 12504    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18127    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 12502    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 12508    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 12509    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 12501    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 12502    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 12498    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18618    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 12507    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 12492    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 12506    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 12509    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 12509    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 12509    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19122    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 12523    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 12517    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 12518    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 12522    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19505    |
# ----------------------------------
# Eval num_timesteps=19520, episode_reward=9.80 +/- 0.40
# Episode length: 9.80 +/- 0.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.8      |
# |    mean_reward      | 9.8      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 19520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 12442    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 12441    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 12439    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 12437    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 12443    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19942    |
# ----------------------------------

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (9.6, 0.4898979485566356)

# %%
env.close()
