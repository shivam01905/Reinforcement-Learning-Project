# %% [markdown]
# # 1. Import Dependencies

# %%
#Install SWIG https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %%
pip install gym==0.21.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FB328846D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/gym/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FB32884A00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/gym/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001FB32884C70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/gym/
# ...

# %%
# !pip install gym[box2d] pyglet

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# # 2. Test Environment

# %%
environment_name = "CarRacing-v1"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1030..1292 -> 262-tiles track
# Episode:1 Score:-27.203065134099937
# Track generation: 1344..1684 -> 340-tiles track
# Episode:2 Score:-41.002949852508124
# Track generation: 1175..1473 -> 298-tiles track
# Episode:3 Score:-32.65993265993315
# Track generation: 1139..1428 -> 289-tiles track
# Episode:4 Score:-30.555555555556005
# Track generation: 967..1220 -> 253-tiles track
# Episode:5 Score:-20.634920634920746

# %%
env.close()

# %%
env.action_space.sample()

# %%
env.observation_space.sample()

# %% [markdown]
# # 3. Train Model

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Track generation: 1201..1505 -> 304-tiles track
# Logging to Training\Logs\PPO_3
# Track generation: 1038..1311 -> 273-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 39   |
# |    iterations      | 1    |
# |    time_elapsed    | 51   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1060..1329 -> 269-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 2           |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005081643 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# ...

# %% [markdown]
# # 4. Save Model

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model1')

# %%
model.save(ppo_path)

# %%
del model

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model1')

# %%
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# D:\ReinforcementLearning\rl\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1173..1477 -> 304-tiles track
# Track generation: 1249..1566 -> 317-tiles track
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1203..1511 -> 308-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1087..1363 -> 276-tiles track
# Track generation: 1233..1542 -> 309-tiles track
# Track generation: 1247..1563 -> 316-tiles track
# Track generation: 1174..1482 -> 308-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1055..1328 -> 273-tiles track
# ...

# %%
env.close()
